# %%
# If you are using an R Kernel in Jupyter, run this cell to install dependencies
install.packages(c("ggplot2", "forecast", "tseries"), repos='http://r-project.org')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # If you are using an R Kernel in Jupyter, run this cell to install dependencies
# ----> 2 install.packages(c("ggplot2", "forecast", "tseries"), repos='http://r-project.org')
#
# NameError: name 'install' is not defined
